# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
mertrics = np.load('metrics.npy')

# %%
print(mertrics)
# Out:
# [3.7103366e-02 2.4813784e-03 4.9813434e-02 2.1268448e-01 6.3517008e+00]

# %%
pred = np.load('pred.npy')
true = np.load('true.npy')

# %%
k = 0
for i, j in zip(pred, true):
    k=k+1
    if k % 500 == 0:
        plt.plot(i)
        plt.plot(j)
        plt.legend(['pred','true'])
        plt.show()

# %%
len(true)
# Out:
# 140
