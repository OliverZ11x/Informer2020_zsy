# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
mertrics = np.load('best_metrics.npy')

# %%
print(mertrics)
# Out:
# [9.3779862e-01 1.3549305e+00 1.1640148e+00 7.6278877e+00 7.1893354e+03]

# %%
pred = np.load('best_pred.npy')
true = np.load('best_true.npy')

# %%
pred.shape
# Out:
# (2240, 200, 1)

# %%
pred = pred.reshape(-1,500,1)
true = true.reshape(-1,500,1)

# %%
for i, j in zip(pred, true):
    plt.plot(i)
    plt.plot(j)
    plt.legend(['pred','true'])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\Recurrence_code\Informer2020_zsy\results\informer_BP_ftS_sl200_ll200_pl0_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0\test.ipynb Cell 7 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/f%3A/Recurrence_code/Informer2020_zsy/results/informer_BP_ftS_sl200_ll200_pl0_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0/test.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(j)
#       <a href='vscode-notebook-cell:/f%3A/Recurrence_code/Informer2020_zsy/results/informer_BP_ftS_sl200_ll200_pl0_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0/test.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> plt.legend(['pred','true'])
# ...

# %%
len(true)
# Out:
# 140
